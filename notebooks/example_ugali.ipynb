# %%
# %matplotlib inline

# %%
import numpy as np
import pylab as plt
from matplotlib.colors import LogNorm

from ugali import isochrone

# %%
def plot_iso(iso):
    plt.scatter(iso.mag_1-iso.mag_2,iso.mag_1+iso.distance_modulus,marker='o',c='k')
    plt.gca().invert_yaxis()
    plt.xlabel('%s - %s'%(iso.band_1,iso.band_2)); plt.ylabel(iso.band_1)

# %%
iso1 = isochrone.factory(name='Padova',
                        age=12,  # Gyr
                        metallicity=0.001, # Z
                        distance_modulus=10,
                        band_1 = 'i',
                        band_2 = 'z'
                       )
print(iso1)
plot_iso(iso1)
# Out:
# Padova
#   Parameters:
#     distance_modulus : Parameter(10, [10.0, 30.0], False)
#     age              : Parameter(12, [1.0, 13.5], False)
#     metallicity      : Parameter(0.001, [0.0001, 0.001], False)
#   Filename: /home/mmestre/.ugali/isochrones/des/marigo2017/iso_a12.0_z0.00100.dat
